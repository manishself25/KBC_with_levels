# %%
print("********** Welcome To Technical KBC Game **********")
import random
import numpy as np
import pandas as pd
import datetime

now = datetime.datetime.now()
year = now.year
month = now.month
day = now.day
hour = now.hour
minute = now.minute
second = now.second
date= f"{day}_{month}_{year}"
time= f"{hour}:{minute}"
player= input("Enter your name : ").title()
# Out:
# ********** Welcome To Technical KBC Game **********
# Enter your name : kunal

# %%
############################# level 1 Questions #################################
questionsl1 = ["Who developed Python Programming Language?\n",
            "Which type of Programming does Python support?\n",
           "Which of the following is the correct extension of the Python file?\n",
           "All keywords in Python are in _________?\n",
            "Which of the following is used to define a block of code in Python language?\n",
            "Python supports the creation of anonymous functions at runtime, using a construct called __________", 
            "What is the order of precedence in python?"]

optionsl1 =[" 1. Wick van Rossum \n 2. Rasmus Lerdorf \n 3. Guido van Rossum \n 4. Niene Stom\n",
          "1. object-oriented programming \n 2. structured programming \n 3. functional programming \n 4. all of the mentioned\n",
          "1. .p \n 2. .pl \n 3. .py \n 4. .python",
          "1. Capitalized \n 2. lower case \n 3. UPPER CASE \n 4. None of the mentioned",
          "1. Indentation \n 2. Key \n 3. Brackets \n 4. All of the mentioned\n",
          "1. pi \n 2. anonymous \n 3. lambda \n 4. none of the mentioned\n",
          "1. Exponential, Parentheses, Multiplication, Division, Addition, Subtraction \n 2. Exponential, Parentheses, Division, Multiplication, Addition, Subtraction \n 3. Parentheses, Exponential, Multiplication, Division, Subtraction, Addition \n 4. Parentheses, Exponential, Multiplication, Division, Addition, Subtraction\n"]

ff_optionsl1=["2. Rasmus Lerdorf \n 3. Guido van Rossum \n",
            "1. object-oriented programming \n  4. all of the mention\n",
            "3. .py \n 4. .python\n",
            "2. lower case \n 4. None of the mentioned\n",
            "1. Indentation \n 3. Brackets\n",
            "3. lambda \n 4. none of the mentioned\n",
            "3. Parentheses, Exponential, Multiplication, Division, Subtraction, Addition \n 4. Parentheses, Exponential, Multiplication, Division, Addition, Subtraction\n"]

correctl1=["3","4","3","4","1","3","4"]

answersl1 = ["3. Guido van Rossum","4. all of the mentioned","3. .py","4. None of the mentioned",
           "1. Indentation","3. lambda","4. Parentheses, Exponential, Multiplication, Division, Addition, Subtraction"]
################################################################################

############################# level 2 Questions #################################
questionsl2 = ["What is the chemical symbol for gold?\n",
            "Which planet is known as the Red Planet?\n",
           "In what year did the Titanic sink?\n",
           "What is the smallest country in the world by land area?\n",
           "Who was the first President of the United States?\n"]

optionsl2 =[" 1. Au \n 2. Ag \n 3. Fe \n 4. Hg\n",
          "1.Venus \n 2. Mars \n 3. Mercury \n 4. Jupiter\n",
          "1. 1905 \n 2. 1910 \n 3. 1912 \n 4. 1915\n",
          "1. Monaco \n 2. Vatican City \n 3. San Marino \n 4. Liechtenstein\n",
          "1. Thomas Jefferson \n 2. John Adams \n 3. Benjamin Franklin \n 4. George Washington\n"]
ff_optionsl2=["1. Au \n 2. Ag \n",
            "2. Mars \n 3. Mercury \n",
            "2. 1910 \n 3. 1912\n",
            "1. Monaco \n 2. Vatican City\n",
            "3. Benjamin Franklin \n 4. George Washington\n"]

correctl2=["1","2","3","2","4"]

answersl2 = ["1. Au","2. Mars","3. 1912","2. Vatican City","4. George Washington"]
################################################################################

############################# level 3 Questions #################################
questionsl3 = ["What is the capital city of Australia?\n",
    "In which year did the Berlin Wall fall?\n",
    "Who developed the theory of relativity?\n",
    "Which gas is most abundant in the Earth's atmosphere?\n",
    "What is the longest river in the world?\n"]

optionsl3 =[" 1. Sydney \n 2. Melbourne \n 3. Canberra \n 4. Brisbane\n",
          "1.1987 \n 2. 1989 \n 3. 1991 \n 4. 1993\n",
          "1. Isaac Newton \n 2. Albert Einstein \n 3. Galileo Galilei \n 4. Nikola Tesla\n",
          "1. Oxygen \n 2. Hydrogen \n 3. Nitrogen \n 4. Carbon Dioxide\n",
          "1.Amazon River \n 2. Nile River \n 3. Yangtze River \n 4. Mississippi River\n"]
ff_optionsl3=["2. Melbourne \n 3. Canberra \n",
            "1.1987 \n 2. 1989 \n",
            "1. Isaac Newton \n 2. Albert Einstein\n",
            "3. Nitrogen \n 4. Carbon Dioxide\n",
            "1.Amazon River \n 2. Nile River\n"]

correctl3=["3","2","2","3","2"]

answersl3 = ["3. Canberra","2. 1989","2. Albert Einstein","3. Nitrogen","2. Nile River"]
################################################################################




# **********************************************************************
lifeline_name=["Fifty Fifty Lifeline","Change the question"]
lifeline_questions=["Which of the following functions can help us to find the version of python that we are currently working on?\n",
                    "Which keyword is used for function in Python language?\n",
                    "What does pip stand for python?\n"]
lifeline_options=["1. sys.version(1) \n 2. sys.version(0) \n 3. sys.version() \n 4. sys.version \n",
                  "1. Function \n 2. def \n 3. Fun \n 4. Define \n",
                  "1. Pip Installs Python \n 2. Pip Installs Packages \n 3. Preferred Installer Program \n 4. All of the mentioned\n"]
lifeline_correct=["4","2","3"]
lifeline_answers = ["4. sys.version","2. def","3. Preferred Installer Program"]
# *************************************************************************
paisa1=[1000,2000,3000,4000,5000]
paisa2=[10000,20000,30000,40000,50000]
paisa3=[100000,2000000,30000000,40000000,50000000]

# %%
def level(tql1,questionsl1,optionsl1,correctl1,answerl1,paisa1,ff_optionsl1,lifeline_questions,lifeline_options,lifeline_correct,lifeline_answers):
    i=0
    while i<5:
        ques=tql1[i]
        qos=questionsl1.index(ques)

        print(ques)
        print(optionsl1[qos])


        player_int= input("Do you know the answer ? (yes or no)\n ").lower()

        if player_int=="yes":
            user_ans=input("Choose the correct option ?\n ")
            if user_ans==correctl1[qos]:
                print("you selected ", answersl1[qos] ," which is a correct answer \n")
                print("Answer is correct, your winning amount is ",paisa1[i])
                prize_money=paisa1[i]
            else:
                print("Incorrect Answer \n ")
                print("correct answer was ", answersl1[qos])
                prize_money = 0
                break
        else:
            lifeline=input("Do you want to take Life Line? or want to Quit ?\n")
            if lifeline=="yes":
                lno=input("Select a lifeline from these options \n 1.Fifty Fifty Lifeline \n 2. Change the question : ")
                if lno=="1":
                    print("you have selected Fifty Fifty Lifeline")
                    print(ff_options[qos])
                    user_ans=input("Choose the correct option \n   \n")
                    if user_ans==correctl1[qos]:
                        print("you selected ", answersl1[qos] ," which is a correct answer\n")
                        print("Answer is correct, your winning amount is ",paisa1[i])
                        prize_money=paisa1[i]
                    else:
                        print("Incorrect Answer \n ")
                        print("correct answer was ", answersl1[qos])
                        prize_money = 0
                        break

                elif lno=="2":
                    los=lifeline_questions.index(lql)
                    print(lql)
                    print(lifeline_options[los])
                    user_ans=input("Choose the correct option \n ")
                    if user_ans==lifeline_correct[los]:
                        print("you selected ", lifeline_answers[los] ," which is a correct answer\n")
                        print("Answer is correct, your winning amount is ",paisa1[i])
                        prize_money=paisa1[i]
                    else:
                        print("Incorrect answer \n ")
                        print("correct answer was ", lifeline_answers[los])
                        prize_money = 0
                        break

            else:
                print("your winning amount transfer in your account is under process")
                break

        i = i+1
    return prize_money

# %%
tql1 =np.random.choice(questionsl1,5, replace=False).tolist()
tql2 =np.random.choice(questionsl2,5, replace=False).tolist()
tql3 =np.random.choice(questionsl3,5, replace=False).tolist()
lql=np.random.choice(lifeline_questions)
prize_money=0

game_on=True
while game_on:
    print(f"--------------------LEVEL 1--------------------")
    a = level(tql1,questionsl1,optionsl1,correctl1,answersl1,paisa1,ff_optionsl1,lifeline_questions,lifeline_options,lifeline_correct,lifeline_answers)
    print("your winning amount is :",a,"\n")
    if a!=5000:
        game_on = False
    break
while game_on:
    print("--------------------LEVEL 2--------------------")
    a = level(tql2,questionsl2,optionsl2,correctl2,answersl2,paisa2,ff_optionsl2,lifeline_questions,lifeline_options,lifeline_correct,lifeline_answers)
    print("your winning amount is :",a,"\n")
    if a!=50000:
        game_on = False
    break
while game_on:
    print("--------------------LEVEL 3--------------------")
    a = level(tql3,questionsl3,optionsl3,correctl3,answersl3,paisa3,ff_optionsl3,lifeline_questions,lifeline_options,lifeline_correct,lifeline_answers)
    print("your winning amount is :",a,"\n")
    break
# Out:
# --------------------LEVEL 1--------------------
# All keywords in Python are in _________?
#
# 1. Capitalized
#  2. lower case
#  3. UPPER CASE
#  4. None of the mentioned
# Do you know the answer ? (yes or no)
#  yes
# Choose the correct option ?
#  4
# you selected  4. None of the mentioned  which is a correct answer
#
# Answer is correct, your winning amount is  1000
# Which type of Programming does Python support?
#
# 1. object-oriented programming
#  2. structured programming
#  3. functional programming
#  4. all of the mentioned
#
# Do you know the answer ? (yes or no)
#  yes
# Choose the correct option ?
#  4
# you selected  4. all of the mentioned  which is a correct answer
#
# Answer is correct, your winning amount is  2000
# Python supports the creation of anonymous functions at runtime, using a construct called __________
# 1. pi
#  2. anonymous
#  3. lambda
#  4. none of the mentioned
#
# Do you know the answer ? (yes or no)
#  yes
# Choose the correct option ?
#  3
# ...
